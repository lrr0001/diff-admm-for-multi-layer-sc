# %%
import pickle
import z_update_layer
import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
import numpy as np
import tensorflow as tf
import tensorflow.keras.optimizers
import tensorflow.nn

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.datasets import cifar10

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

# %%
(xtrain,ytrain),(xtest,ytest) = cifar10.load_data()

# %%
import numpy
def rgb2grey(rgb):
    return numpy.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
xtraingray = rgb2grey(xtrain)
xtraingray = numpy.reshape(xtraingray,(-1,32,32,1))
xtestgray = rgb2grey(xtest)
xtestgray = numpy.reshape(xtestgray,(-1,32,32,1))

# %%
ytrainCat = to_categorical(ytrain)
ytest = to_categorical(ytest)

# %%
model1 = Sequential([preprocessing.Local_contrast_normalization(12,1,input_shape=(32,32,1))])
model2 = Sequential([preprocessing.Local_contrast_normalization(12,2,input_shape=(32,32,1))])
model3 = Sequential([preprocessing.Local_contrast_normalization(12,3,input_shape=(32,32,1))])
model4 = Sequential([preprocessing.Local_contrast_normalization(12,4,input_shape=(32,32,1))])
# Out:
# WARNING:tensorflow:From /home/lrr/anaconda3/envs/tfEnv0/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py:255: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
output = model1.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
output = model2.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
output = model3.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
output = model4.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
model5 = Sequential([preprocessing.Local_contrast_normalization(12,5,input_shape=(32,32,1))])
model6 = Sequential([preprocessing.Local_contrast_normalization(12,6,input_shape=(32,32,1))])
model7 = Sequential([preprocessing.Local_contrast_normalization(12,7,input_shape=(32,32,1))])
model8 = Sequential([preprocessing.Local_contrast_normalization(12,8,input_shape=(32,32,1))])

# %%
output = model5.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
output = model6.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
output = model7.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
output = model8.predict(xtraingray[0:2])
plt.imshow(numpy.squeeze(output[0]),cmap='gray')

# %%
from tensorflow.keras.datasets import mnist

# %%
(xtrain,ytrain),(xtest,ytest) = cifar10.load_data()
